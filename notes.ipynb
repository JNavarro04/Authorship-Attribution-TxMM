# %% [markdown]
# A3 – Notes LOLA
# 1. Classifier Training
# Tested Logistic Regression, Linear SVM and Random Forest.
# Logistic Regression achieved the highest initial dev Macro F1 (0.8599).
# Tuned C using 5-fold cross-validation. C = 0.1 improved dev F1 to 0.8654.
#
# 3. Ablation Analysis
# Removed each feature group separately and retrained the model.
# Removing function words caused the largest F1 drop (0.0637).
# Keep all four feature groups.
#
# 4. Feature Selection
# Check whether removing less informative features could improve performance.
# Tested SelectKBest with different numbers of features.
# Using all 182 features achieved the highest cross-validation F1 (0.9119).
#
# 6. Final Evaluation
# Test Macro F1 = 0.9066; accuracy = 91.76%.
# Created a row-normalized confusion matrix with totals to make the errors and accuracy per author easier to interpret.
#
# What problems could you solve with 10 extra hours?
# Investigate why authors 1497577 and 870118 are frequently confused and compare their linguistic features to identify possible similarities.
# Experiment with additional features from the Sockpuppet paper, such as letter frequencies, repeated punctuation and contractions.Evaluate whether these new features reduce the errors.
